# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go

# %%
dados = pd.read_csv('https://data.insideairbnb.com/united-states/ma/boston/2024-06-22/visualisations/listings.csv')
dados
# Out:
#                        id                                              name  \
# 0                    3781                         HARBORSIDE-Walk to subway
# 1                    5506    ** Fort Hill Inn Private! Minutes to center!**
# 2                    6695     Fort Hill Inn *Sunny* 1 bedroom, condo duplex
# 3                    8789               Curved Glass Studio/1bd facing Park
# 4                   10811  Back Bay Apt Studio-3 blocks to Pru center & "T"
# ...                   ...                                               ...
# 4320  1181310640039457019        The Chester: Modern Luxury, Historic Charm
# 4321  1181310920532325010         The Chester:  Urban Luxury, Modern Design
# 4322  1181311064422167794     The Chester: Modern, Cool, Heart Of South End
# 4323  1182535715185750063                                Luxury one bedroom
# 4324  1183366210963015944       Large 4 Bedroom apartments, 2RD FL/Brighton
#
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4325 non-null   int64
#  1   name                            4325 non-null   object
#  2   host_id                         4325 non-null   int64
#  3   host_name                       4325 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   4325 non-null   object
#  6   latitude                        4325 non-null   float64
#  7   longitude                       4325 non-null   float64
#  8   room_type                       4325 non-null   object
#  9   price                           3543 non-null   float64
#  10  minimum_nights                  4325 non-null   int64
#  11  number_of_reviews               4325 non-null   int64
# ...

# %%
dados.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
dados = dados.drop('neighbourhood_group', axis=1)
dados = dados.dropna()
dados
# Out:
#                        id                                             name  \
# 1                    5506   ** Fort Hill Inn Private! Minutes to center!**
# 2                    6695    Fort Hill Inn *Sunny* 1 bedroom, condo duplex
# 9                   40601              Private room & bath - Jamaica Plain
# 10                  45987                                    Garden Studio
# 11                  47521  Private Room, shared bath in Victorian House/ 1
# ...                   ...                                              ...
# 4286  1175344947100869764              Huge Studio in Downtown Boston 1409
# 4292  1176861035408746030         Cozy Boston studio with separate bedroom
# 4293  1177103248225483462   Stylish studio with room divider near downtown
# 4296  1177619455488589855                       Luxury South End 1 Bedroom
# 4301  1178933965841931292  Best Location, 1 bedroom Apartment, Beacon Hill
#
#         host_id host_name  neighbourhood   latitude  longitude  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2214 entries, 1 to 4301
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2214 non-null   int64
#  1   name                            2214 non-null   object
#  2   host_id                         2214 non-null   int64
#  3   host_name                       2214 non-null   object
#  4   neighbourhood                   2214 non-null   object
#  5   latitude                        2214 non-null   float64
#  6   longitude                       2214 non-null   float64
#  7   room_type                       2214 non-null   object
#  8   price                           2214 non-null   float64
#  9   minimum_nights                  2214 non-null   int64
#  10  number_of_reviews               2214 non-null   int64
#  11  last_review                     2214 non-null   object
# ...

# %%
def geraHistograma(titulo,nomeEixoX,dadosEixo,cor,altura,largura,numeroBarras):
  if numeroBarras=="":
    numeroBarras=None
  # criação de uma figure para montar o histograma
  fig = go.Figure()
  # gera o histograma
  fig.add_trace(go.Histogram(x=dadosEixo,marker_line=dict(width=1, color='black'),marker_color=cor,nbinsx=numeroBarras))
  #define layout do gráfico
  fig.update_layout(
      height=altura,
      width=largura,
      title_text=titulo,
      title_font_size=20,
      xaxis_title=nomeEixoX
      )
  fig.show()
  return

# %%
geraHistograma(
    titulo="Histograma de Price",
    nomeEixoX="Price",
    dadosEixo=dados['price'],
    cor="blue",
    altura=400,
    largura=800,
    numeroBarras="")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 geraHistograma(
#       2     titulo="Histograma de Price",
#       3     nomeEixoX="Price",
#       4     dadosEixo=dados['price'],
#       5     cor="blue",
#       6     altura=400,
#       7     largura=800,
#       8     numeroBarras="")
#
# Cell In[94], line 16, in geraHistograma(titulo, nomeEixoX, dadosEixo, cor, altura, largura, numeroBarras)
#       8 #define layout do gráfico
#       9 fig.update_layout(
#      10     height=altura,
#      11     width=largura,
#    (...)
#      14     xaxis_title=nomeEixoX
#      15     )
# ---> 16 fig.show()
#      17 return
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
# ...
